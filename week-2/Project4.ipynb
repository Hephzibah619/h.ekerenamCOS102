# %%
#Devoloping a Project for IZIFIN TECHNOLOGY FOR ANNUAL TAX REVENUE(ATR)
        
exp = int(input("How much years of experience"))
age = int(input("How old are you"))


if exp > 25 and age >= 55:
          print("Annual Tax Revenue(ATR) : N5,600,000")
           
elif exp > 20 and age >= 45:
          print("Annual Tax Revenue(ATR) : N4,480,000")

elif exp > 10 and age >= 35:
          print("Annual Tax Revenue(ATR) : N15,000,000")

elif exp > 10 and age < 35:
          print("Annual Tax Revenue(ATR) : N55,000")
else:
          print("Thanks For Working with us")
# Out:
# How much years of experience 45
# How old are you 55
# Annual Tax Revenue(ATR) : N5,600,000
