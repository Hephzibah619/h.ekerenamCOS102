# %%
#Python program to swap two cities

#To take inputs from the user 
city_1 = input('Enter name of city 1: ')
city_2 = input('Enter name of city 2: ')

#creat a temporary variable and swap the cities 
temp = city_1
city_1 = city_2
city_2 = temp

print(f"The name of City 1 after swapping is {city_1}")
print(f"name of the city 2 after swapping is {city_2}")
# Out:
# Enter name of city 1:  lagos
# Enter name of city 2:  hephzibah
# The name of City 1 after swapping is hephzibah
# name of the city 2 after swapping is lagos
