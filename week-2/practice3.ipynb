# %%
#COUPE DE ESCRIVA 2023: FOOTBALL PICKS

print ("welcome to the COUPE DE ESCRIVA 2023:FOOTBALL PICKS \n")

captain = {'Madiba: ':'Chubby Obiora-ohafo', 'Blue-Jays: ': 'Christopher Uweh', 
           'cirok: ':'Alexandar', 'TSG Walkers: ' :'Ikechuku'}
goalkeepers = {'Madiba: ': 'Chubby Obiora-Okafo','Blue-Jays: ':'Olandimeji Abaniwondea/Jeffery Awagu','Cirok: ':'Timileyin Pearse/Izuko Jeremy',
               'TSG Walkers: ': 'Ayomide Ojituku'}
for pick in captain:
    print(pick, captain[pick])

print("\n")

for pick in goalkeepers:
    print(pick,goalkeepers[pick])
# Out:
# welcome to the COUPE DE ESCRIVA 2023:FOOTBALL PICKS
#
# Madiba:  Chubby Obiora-ohafo
# Blue-Jays:  Christopher Uweh
# cirok:  Alexandar
# TSG Walkers:  Ikechuku
#
#
# Madiba:  Chubby Obiora-Okafo
# Blue-Jays:  Olandimeji Abaniwondea/Jeffery Awagu
# Cirok:  Timileyin Pearse/Izuko Jeremy
# TSG Walkers:  Ayomide Ojituku
